# %%
import xarray as xr

# %%
## Glacier
path = '../data/out/Belli_glacier_200.nc'
ds   = xr.open_dataset(path) 
df_gla = ds[['smb', 'Accu', 'Melt', 'Q']].mean(('lon', 'lat')).to_dataframe().loc['1960':'2020']

# %%
df_gla['smb']['20100401':'20150331'].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
ds['smb'][18].plot()
